# %%
print("Helo GreatEdu")
# Out:
# Helo GreatEdu

# %% [markdown]
# **Ini belajar awal menggunakan Pyhton**

# %% [markdown]
# # Header 1
# ## Header 2
# ### Header 3

# %% [markdown]
# [Google](http://www.google.com/)
# [Python](https://www.python.org/ "Python[link text](https://)")

# %% [markdown]
# 1. Basic Type Object
#     * Numbers
#     * Strings
#     * Boolean
#     * List
# 2. Structure Data

# %%
print("Halo GreatEdu")
print("panjang = 100")
print("lebar = 23")
# Out:
# Halo GreatEdu
# panjang = 100
# lebar =23

# %%
print("luas = panjang * lebar")
# Out:
# luas = panjang * lebar

# %%
usia = 20
if usia >= 7:
  print("diterima masuk SD")
  print("dinyatakan lulus")
else:
  print("tidak diterima masuk SD")
  print("dinyatakan gagal")
# Out:
# diterima masuk SD
# dinyatakan lulus

# %%
namadepan = 'Doni'
namalengkap = """Arief 
Rama Syarif"""
Alinea = """Ini adalah alinea yang 
terdiri dari beberapa baris"""

print(namadepan)
print(namalengkap)
print(Alinea)
# Out:
# Doni
# Arief
# Rama Syarif
# Ini adalah alinea yang
# terdiri dari beberapa baris

# %%
panjang = 15
lebar = 3
luas = panjang*lebar

print(luas)
# Out:
# 45

# %%
a=10
print("a")
# Out:
# a

# %%
nama_hari = ['Senin','Selasa','Rabu','Kamis','Jumat','Sabtu']
print(nama_hari)
# Out:
# ['Senin', 'Selasa', 'Rabu', 'Kamis', 'Jumat', 'Sabtu']

# %%
penjumlahan=2+3
print(penjumlahan)
# Out:
# 5

# %%
pengurangan=5-4
print(pengurangan)
# Out:
# 1

# %%
x=2
x+=10
print(x)
# Out:
# 12

# %%
x1=2
x1/=10
print(x1)
# Out:
# 0.2

# %% [markdown]
# **Operator AND**

# %%
a = 5
b = 10
print (a and b < 25)
# Out:
# True

# %% [markdown]
# **Operator OR**

# %%
c = 0
d = 10
print (c > 10 or d > 10)
# Out:
# False

# %% [markdown]
# **Operato NOT**

# %%
e = 25
f = 30
print (not(e and f > 100))
# Out:
# True

# %% [markdown]
# **String Manipulation**

# %%
#Manipulasi string dengan index 0 dari kata Hello
kata_hebat = "Hello"
kata_hebat[0]
# Out:
# 'H'

# %%
kata_hebat = "Hello"
kata_hebat[:2]
# Out:
# 'He'

# %%
kata_hebat = "Hello"
kata_hebat[:-3]
# Out:
# 'He'

# %%
kata_hebat = "Hello"
kata_hebat.upper()
# Out:
# 'HELLO'

# %%
kata_hebat = "Hello"
kata_hebat.lower()
# Out:
# 'hello'

# %%
kata_hebat = "Hello"
kata_tambahan = kata_hebat + ", GreatEdu"
len(kata_tambahan)
# Out:
# 15

# %%
lakes = ['superior', 'erie', 'huron', 'ontario', 'powell']
len(lakes)
# Out:
# 5

# %%
#Operator +
print("Py" + "thon")
prefiks = "di"
dasar_1 = "terima"
dasar_2 = "tolak"
print(prefiks + dasar_1)
print(prefiks, dasar_2)
print("Py" "thon")
# Out:
# Python
# diterima
# di tolak
# Python

# %%
#Tanda \ dan r
#Tanda \ berguna sebagai penginterpretasi karakter spesial sedangkan r membuat string menjadi terbaca sebagai raw strings (apa adanya)
print("ganti baris \n ke bawah")  # \n turun satu baris
#print("C:\user\folder") # error
print(r"C:\user\folder") # berhasil
# Out:
# ganti baris
#  ke bawah
# C:\user\folder

# %% [markdown]
# **List Function**
#
# len, sum, any, all,  sorted

# %%
lakes = ['Superior','erie','huron','ontario','powell']
len(lakes)
# Out:
# 5

# %%
number = [1, 2, 3, 4, 5]
sum(number)
# Out:
# 15

# %%
max(number)
# Out:
# 5

# %%
min(number)
# Out:
# 1

# %%
lakes_sorted = sorted(lakes)
lakes_sorted
# Out:
# ['Superior', 'erie', 'huron', 'ontario', 'powell']

# %% [markdown]
# **Various List Methods**

# %%
Kota = ['Jakarta','Jakarta','Bandung','Bandung','Semarang','Jogja','Surabaya']
Kota
# Out:
# ['Jakarta', 'Jakarta', 'Bandung', 'Bandung', 'Semarang', 'Jogja', 'Surabaya']

# %%
#Hitung jumlah kata Semarang dalam list kota
Kota.count('Semarang')
# Out:
# 2

# %%
#Hitung jumlah kata Jakarta dalam list kota
Kota.count('Jakarta')
# Out:
# 2

# %%
#Hitung jumlah kata Jakarta dalam list kota
Kota.count('Bandung')
# Out:
# 2

# %%
Kota.append('Semarang')
Kota
# Out:
# ['Jakarta',
#  'Jakarta',
#  'Bandung',
#  'Bandung',
#  'Semarang',
#  'Jogja',
#  'Surabaya',
#  'Semarang']

# %%
#Hitung jumlah kata Semarang dalam list kota
Kota.count('Semarang')
# Out:
# 2

# %%
Kota.sort()
Kota
# Out:
# ['Bandung',
#  'Bandung',
#  'Jakarta',
#  'Jakarta',
#  'Jogja',
#  'Semarang',
#  'Semarang',
#  'Surabaya']

# %%
Kota.pop()
Kota
# Out:
# ['Bandung', 'Bandung', 'Jakarta', 'Jakarta', 'Jogja', 'Semarang', 'Semarang']

# %%
Kota.remove("Semarang")
Kota
# Out:
# ['Bandung', 'Bandung', 'Jakarta', 'Jakarta', 'Jogja', 'Semarang']

# %%
tambah_kota_banyak = ["Palembang","Medan"]
Kota.extend(tambah_kota_banyak)
Kota
# Out:
# ['Bandung',
#  'Bandung',
#  'Jakarta',
#  'Jakarta',
#  'Jogja',
#  'Semarang',
#  'Palembang',
#  'Medan']

# %%
Kota.pop()
Kota
# Out:
# ['Bandung', 'Bandung', 'Jakarta', 'Jakarta', 'Jogja', 'Semarang', 'Palembang']
